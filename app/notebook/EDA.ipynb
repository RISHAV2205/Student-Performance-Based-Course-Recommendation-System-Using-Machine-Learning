# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"D:\academics\project\Performance_Based_Recommendation\Data\student_data.csv")
data.head()

# %%
data.info()

# %%
data.isnull().sum()

# %%
data.describe()

# %%
sns.histplot(data["G3"], bins=20)
plt.title("Final Grade Distribution")
plt.xlabel("Final Grade")
plt.show()

# %% [markdown]
# Study Time vs Performance

# %%
sns.boxplot(x="studytime", y="G3", data=data)
plt.title("Study Time vs Final Grade")
plt.show()

# %% [markdown]
# Failures vs Performance

# %%
sns.boxplot(x="failures", y="G3", data=data)
plt.title("Failures vs Final Grade")
plt.show()

# %% [markdown]
# Absences vs Performance

# %%
sns.scatterplot(x="absences", y="G3", data=data)
plt.title("Absences vs Final Grade")
plt.show()

# %% [markdown]
# correlation matrix

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Feature Correlation Matrix")
plt.show()

# %% [markdown]
# G1 and G2 strongly correlated with final grade G3

# %% [markdown]
# Gender and performance

# %%
sns.boxplot(x="sex", y="G3", data=data)
plt.title("Gender vs Final Grade")
plt.show()

# %% [markdown]
# Male and female students show similar performance.

# %% [markdown]
# Create Performance Category

# %%
def performance(score):
    if score < 10:
        return "Weak"
    elif score < 15:
        return "Average"
    else:
        return "Strong"
data["Performance"] = data["G3"].apply(performance)

# %%
data["Performance"].value_counts()

# %%
data.head()
